# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

print("프로그램 시작")
now = time.time()

chromedriver = '.\webdirver\chromedriver'
driver = webdriver.Chrome(chromedriver)
driver.get('http://www.naver.com')

print("브라우저 실행 %0.2f초 경과" % (time.time() - now))

# 해당 링크(페이지)의 제목
# print(driver.title)
# 해당 페이지의 html 소스
# print(driver.page_source) 
# 해당 페이지의 url 주소
# print(drvier.current_url)

# 해당 객체에서 임의의 데이터가 있으면 정상 실행, 아닌 경우 에러 발생
# assert 'NAVER' in driver.title
# assert "No results found." not in driver.page_source

# name 속성 요소 탐색
elem = driver.find_element_by_name("query")  # naver 창의 search box의 name
elems = driver.find_elements_by_tag_name("a")
elem2 = driver.find_element_by_id("")
elem3 = driver.find_element_by_class_name("")  # 리턴 형태가 무엇 ?
# elems3 = driver.find_elements_by_class_name("") # 가능 ?
elem4 = drvier.find_element_by_css_selector("")
elem5 = find_element_by_xpath("")
# BeautifylSoup 지원 x
# XPath : XML 문서의 특정 요소나 속성에 접근하기 위한 경로를 지정
elem6 = find_element_by_css_selector("div[role = 'navigation']")


print(elems)

# searchbox 초기화
elem.clear()

# 키 이벤트 전송
elem.send_keys("장만춘")

# 의도적인 시간 지연, 단위: 초, 검색 결과가 나오는데 시간이 걸리는 경우에 사용
time.sleep(5)
print("타임 슬립 %0.2f초 경과" % (time.time() - now))

# dir(Keys) # 키 이벤트 목록 

# enter 키 이벤트
elem.send_keys(Keys.RETURN)

# 브라우저 닫기
driver.quit()
# Out:
# 프로그램 시작
# 브라우저 실행 4.51초 경과
# ...
