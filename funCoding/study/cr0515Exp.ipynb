# %%
import openpyxl
import re
regex = re.compile(' [A-Za-z]+\.')

work_book = openpyxl.load_workbook('./excel/train.xlsx')
work_sheet = work_book.active

for row in work_sheet.rows:
    print(regex.findall(row[3].value))
    
work_book.close()
# Out:
# []
# [' Mr.']
# [' Mrs.']
# [' Miss.']
# [' Mrs.']
# [' Mr.']
# [' Mr.']
# [' Mr.']
# [' Master.']
# [' Mrs.']
# [' Mrs.']
# [' Miss.']
# [' Miss.']
# [' Mr.']
# [' Mr.']
# [' Miss.']
# [' Mrs.']
# [' Master.']
# [' Mr.']
# [' Mrs.']
# [' Mrs.']
# [' Mr.']
# [' Mr.']
# [' Miss.']
# [' Mr.']
# [' Miss.']
# [' Mrs.']
# [' Mr.']
# [' Mr.']
# [' Miss.']
# [' Mr.']
# [' Don.']
# [' Mrs.']
# [' Miss.']
# [' Mr.']
# [' Mr.']
# [' Mr.']
# [' Mr.']
# [' Mr.']
# [' Miss.']
# [' Miss.']
# [' Mrs.']
# [' Mrs.']
# [' Mr.']
# [' Miss.']
# [' Miss.']
# [' Mr.']
# [' Mr.']
# [' Miss.']
# [' Mr.']
# [' Mrs.']
# [' Master.']
# [' Mr.']
# [' Mrs.']
# [' Mrs.']
# [' Mr.']
# [' Mr.']
# [' Miss.']
# [' Mr.']
# [' Miss.']
# [' Master.']
# [' Mr.']
# [' Miss.']
# [' Mr.']
# [' Master.']
# [' Mr.']
# [' Master.']
# [' Mrs.']
# [' Mr.']
# [' Miss.']
# [' Mr.']
# [' Mr.']
# [' Miss.']
# [' Mr.']
# [' Mr.']
# [' Mr.']
# [' Mr.']
# [' Mr.']
# [' Mr.']
# [' Master.']
# [' Miss.']
# [' Mr.']
# [' Mr.']
# ...

# %%
mystr = ['ABCabcABCabc']
mystr.findall('A')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-23cf6e07ee63> in <module>
#       1 mystr = ['ABCabcABCabc']
# ----> 2 mystr.findall('A')
#
# AttributeError: 'list' object has no attribute 'findall'
